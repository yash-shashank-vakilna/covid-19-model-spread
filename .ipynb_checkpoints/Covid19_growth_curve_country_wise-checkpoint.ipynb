# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## Importing Raw data and getting country-wide stats

# %%
raw_data = pd.read_csv('covid_19_data.csv')
del raw_data['Province/State']
del raw_data['SNo']
del raw_data['Last Update']

raw_data['ObservationDate'] = pd.to_datetime(raw_data['ObservationDate'], infer_datetime_format=True)
country_df = raw_data.groupby(['Country/Region','ObservationDate']).agg(np.sum)

# %%
def compute_r_squared(observed_data, fitted_data):
    ss_res = np.sum((observed_data-fitted_data)**2)
    ss_tot = np.sum((observed_data-np.mean(observed_data))**2)
    
    r_squared = 1 - (ss_res / ss_tot)
    return r_squared

# %% [markdown]
# ## Cases in china fits logistic growith curve

# %%
sp_country_df = country_df.loc['Mainland China']

confirm_cases = sp_country_df['Confirmed'].to_numpy()
days =  np.arange(len(confirm_cases))

def logit_fun(x,K,G,Dm ):
    return K/(1+np.exp(-G*(x-Dm)))

popt_logit, pcov_logit = curve_fit(logit_fun, 
            days, confirm_cases, 
            p0=[8e5,0.2,18])

fit_data = logit_fun(days, popt_logit[0], popt_logit[1], popt_logit[2])
nl='\n'
plt.scatter(days,confirm_cases,label='Empirical data')
plt.plot(days, fit_data, 'k--', label=f"""Fit data K={np.round(popt_logit[0])},
         {nl} G={np.round(popt_logit[1],2)}, Dm={np.round(popt_logit[2],2)}""")

plt.xlabel('Days'); plt.ylabel('Confirmed cases')
plt.legend()

print(f'Doubling event = {np.round(1+np.log(2)/popt_logit[1],2)} days')
print(f'R-squared = {np.round(compute_r_squared(confirm_cases,fit_data),3)}')
# Out:
# Doubling event = 4.11 days
# R-squared = 0.995

# %% [markdown]
# ## Cases in US fits exponential growth curve

# %%
def exponential_fun(x,x0,r ):
    return x0*(1+r)**x

sp_country_df = country_df.loc['US']

confirm_cases = sp_country_df['Confirmed'].to_numpy()
days =  np.arange(len(confirm_cases))

popt_expo, pcov_expo = curve_fit(exponential_fun, 
            days, confirm_cases, 
            p0=[1,1])

fit_data = exponential_fun(days, popt_expo[0], popt_expo[1])
nl='\n'
plt.scatter(days,confirm_cases,label='Empirical data')
plt.plot(days, fit_data, 'k--',label=f"Fit data x0={np.round(popt_expo[0],5)}, r={np.round(popt_expo[1],2)}")

plt.xlabel('Days'); plt.ylabel('Confirmed cases')
plt.legend()

print(f'Doubling event = {1+np.round(np.log(2)/(np.log(1+popt_expo[1])),2)} days')
print(f'R-squared = {np.round(compute_r_squared(confirm_cases,fit_data),3)}')
# Out:
# Doubling event = 3.38 days
# R-squared = 0.992

# %% [markdown]
# ## Cases in Italy fits exponential growth curve

# %%
sp_country_df = country_df.loc['Italy']

confirm_cases = sp_country_df['Confirmed'].to_numpy()
days =  np.arange(len(confirm_cases))

popt_expo, pcov_expo = curve_fit(exponential_fun, 
            days, confirm_cases, 
            p0=[1,1])

fit_data = exponential_fun(days, popt_expo[0], popt_expo[1])
nl='\n'
plt.scatter(days,confirm_cases,label='Empirical data')
plt.plot(days, fit_data, 'k--',label=f"Fit data x0={np.round(popt_expo[0],2)}, r={np.round(popt_expo[1],2)}")

plt.xlabel('Days'); plt.ylabel('Confirmed cases')
plt.legend()

print(f'Doubling event = {np.round(1+(np.log(2)/(np.log(1+popt_expo[1]))),2)} days')
print(f'R-squared = {np.round(compute_r_squared(confirm_cases,fit_data),3)}')
# Out:
# Doubling event = 4.39 days
# R-squared = 0.996

# %% [markdown]
# ## Cases in South Korea fits logistic growth curve

# %%
sp_country_df = country_df.loc['South Korea']

confirm_cases = sp_country_df['Confirmed'].to_numpy()
days =  np.arange(len(confirm_cases))

def logit_fun(x,K,G,Dm ):
    return K/(1+np.exp(-G*(x-Dm)))

popt_logit, pcov_logit = curve_fit(logit_fun, 
            days, confirm_cases, 
            p0=[8e5,0.2,18])

fit_data = logit_fun(days, popt_logit[0], popt_logit[1], popt_logit[2])
nl='\n'
plt.scatter(days,confirm_cases,label='Empirical data')
plt.plot(days, fit_data, 'k--', label=f"""Fit data K={np.round(popt_logit[0])},
         {nl} G={np.round(popt_logit[1],2)}, Dm={np.round(popt_logit[2],2)}""")

plt.xlabel('Days'); plt.ylabel('Confirmed cases')
plt.legend()

print(f'Doubling event = {np.round(1+np.log(2)/popt_logit[1],2)} days')
print(f'R-squared = {np.round(compute_r_squared(confirm_cases,fit_data),4)}')
# Out:
# Doubling event = 2.95 days
# R-squared = 0.9996

# %% [markdown]
# ## Cases in India fits exponential growth curve

# %%
sp_country_df = country_df.loc['India']

confirm_cases = sp_country_df['Confirmed'].to_numpy()
days =  np.arange(len(confirm_cases))

popt_expo, pcov_expo = curve_fit(exponential_fun, 
            days, confirm_cases, 
            p0=[1,1])

fit_data = exponential_fun(days, popt_expo[0], popt_expo[1])
nl='\n'
plt.scatter(days,confirm_cases,label='Empirical data')
plt.plot(days, fit_data, 'k--',label=f"Fit data x0={np.round(popt_expo[0],2)}, r={np.round(popt_expo[1],2)}")

plt.xlabel('Days'); plt.ylabel('Confirmed cases')
plt.legend()

print(f'Doubling event = {np.round(1+(np.log(2)/(np.log(1+popt_expo[1]))),2)} days')
print(f'R-squared = {np.round(compute_r_squared(confirm_cases,fit_data),3)}')
# Out:
# Doubling event = 4.73 days
# R-squared = 0.94
